# %%
# Last ran on June 7th, 2018 with Python Version 2.7.15
# Import the necessary packages for CustomSearch to work
# These packages can be installed through 'conda install' or 'pip install'

from googleapiclient.discovery import build
import pprint
import pandas as pd

# %%
import urllib.request
url = "https://cse.google.com/cse?cx=006862296626946594685:yc4sh9rnynu"
request = urllib.request.Request(url)
response = urllib.request.urlopen(request)
print (response.read().decode('utf-8'))
# Out:
# <!doctype html><html lang="id"><head><meta content="text/html; charset=UTF-8" http-equiv="content-type"><link href="https://www.google.com/favicon.ico" rel="icon" type="image/x-icon"><link href="https://fonts.googleapis.com/css?family=Product+Sans" rel="stylesheet" nonce="TSjyiQsZJ4RadG7MN/B8ww=="><title>Google Custom Search</title><script type="text/javascript" nonce="TSjyiQsZJ4RadG7MN/B8ww==">(function(){var relativeUrl='/cse.js?ie\x3dUTF-8\x26hpg\x3d1\x26cx\x3d006862296626946594685:yc4sh9rnynu';(function(){var gcse = document.createElement('script');gcse.type = 'text/javascript';gcse.async = true;gcse.src = relativeUrl;var s = document.getElementsByTagName('script')[0];s.parentNode.insertBefore(gcse,s);})();})();</script><style>body{background-color:#FFFFFF;color:#333333;font-family:arial,sans-serif}#DZPTFe{display:none}#cse-header{width:800px;overflow:auto;padding:10px 4px}#cse-logo{float:left;border:none;direction:ltr}#cse-logo{margin-top:6px}#cse-logo-target{color:#000;text-decoration:none}#cse-search-form{width:22em;float:left;}#cse-search-form{padding-left:16px}#cse{width:100%}#cse-footer{clear:both;font-size:82%;text-align:center;padding:16px}.gsc-control-cse{padding:1%;padding-top:10px}.gsc-branding{display:none}.gsc-adBlock{padding-bottom:10px}.gs-webResult{width:42em;padding:2px 0}.gsc-result .gs-title{height:1.25em}.gs-title,.gs-promotion a{font-weight:normal}.gsc-results .gsc-cursor-box{text-align:center;width:99%;margin-left:auto;margin-right:auto}.gsc-webResult,.gsc-imageResult-classic,.gsc-imageResult-column{margin-bottom:10px;padding:0}.gs-webResult div.gs-visibleUrl-short{display:none}.gs-webResult div.gs-visibleUrl-long{display:block}.gsc-clear-button{display:none}.hidden{display:none}</style></head><body><noscript><h3>Google Custom Search requires JavaScript</h3><p>JavaScript is either disabled or not supported by your browser. To use Custom Search, enable JavaScript by changing your browser options and reloading this page.</p></noscript><div id="cse-hosted"><div id="cse-header"><div class="gcse-searchbox" id="cse-search-form"></div></div><div id="cse-body"><div id="cse"><div class="gcse-searchresults" data-queryParameterName="q"> </div><div class="gsc-adBlock gsc-branding gsc-clear-button gsc-control-cse gsc-cursor-box gsc-imageResult-classic gsc-imageResult-column gsc-result gsc-results gsc-webResult gs-promotion gs-title gs-visibleUrl-long gs-visibleUrl-short gs-webResult hidden" id="DZPTFe"></div></div></div><div id="cse-footer">&copy;&nbsp;2020&nbsp;Google</div></div></body></html>

# %% [markdown]
# ## People Search

# %%
# These can be found on your Cloud Console and Custom Search Engine dashboard, respectively
my_api_key = "AIzaSyCofCDfenbzRaVJhgQhJ4NiS7zExM2pi-w"
my_cse_id = "006862296626946594685:1h5arcdcn0t"

def google_search(search_term, api_key, cse_id, **kwargs):
    service = build("customsearch", "v1", developerKey=api_key)
    res = service.cse().list(q=search_term, cx=cse_id, **kwargs).execute()
    return res['items']

# Search for names here. In lieu of a list, you can try reading in a list of
# names with an Excel or CSV file with Pandas
# search_parameters = ["Forest Fire", "wildfire", "wildland fire", "forest fire", "wildfire", "wildland fire", "forest fire", "wildfire", "wildland fire", "kebakaran hutan", "kabakaran hutan", "kebakaran lahan", "kebakaran hutan dan lahan", "kahutla", "kebakaran hutan", "kebakaran lahan", "kebakaran hutan dan lahan", "kahutla", "kebakaran hutan", "kebakaran lahan", "kebakaran hutan", "karhutla"]
search_parameters = ["Forest Fire", "wildfire", "wildland fire", "forest fire", "wildfire", "wildland fire", "forest fire", "wildfire", "wildland fire",]
results = []

# The free version of Google API limits you to 100 queries per day
# If you require more, it is $5 per additional 1,000 queries
for names in search_parameters :
    results.append(google_search(names, my_api_key, my_cse_id, num=10))

# %%
# The JSON that the search gives is added on to a dictionary. 
# The first entry is the name that you searched
# The second number gives the individual hits from Google
results[0][0].keys()
# Out:
# dict_keys(['kind', 'title', 'htmlTitle', 'link', 'displayLink', 'snippet', 'htmlSnippet', 'cacheId', 'formattedUrl', 'htmlFormattedUrl', 'pagemap'])

# %%
# Results are returned in JSON format 

for result in results:
    pprint.pprint(result)
# Out:
# [{'cacheId': 'Zm-YkDTUGKwJ',
#   'displayLink': 'www.malaymail.com',
#   'formattedUrl': 'https://www.malaymail.com/news/malaysia/...if...forest-fire.../1792209',
#   'htmlFormattedUrl': 'https://www.malaymail.com/news/malaysia/...if...<b>forest</b>-<b>fire</b>.../1792209',
#   'htmlSnippet': 'Sep 19, 2019 <b>...</b> PUTRAJAYA, Sept 19 — The government '
#                  'will not protect the four Malaysian <br>\n'
#                  'companies alleged to have caused the <b>forest fires</b> in '
#                  'Indonesia if&nbsp;...',
#   'htmlTitle': 'Kok: Malaysian companies won&#39;t be protected if Indonesian '
#                '<b>forest</b> ...',
#   'kind': 'customsearch#result',
#   'link': 'https://www.malaymail.com/news/malaysia/2019/09/19/kok-malaysian-companies-wont-be-protected-if-indonesian-forest-fire-claims/1792209',
#   'pagemap': {'cse_image': [{'src': 'https://media.malaymail.com/resize_cache/uploads/articles/2019/2019-09/000_1KD08R-seo.jpg'}],
#               'cse_thumbnail': [{'height': '163',
#                                  'src': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcQjJq-k_NkQpvGVpIxFcH96eixlgC3xyd-pL-EW962hmxzX5cAd0N640xO0',
#                                  'width': '310'}],
#               'metatags': [{'dailymotion-domain-verification': 'dmo5qgk0uy3qakucb',
#                             'fb:app_id': '1709756459249190',
#                             'fb:pages': '163335377171805',
#                             'msapplication-square150x150logo': 'https://www.malaymail.com/graphics/meta/main/logo-150x150.png',
#                             'msapplication-wide310x150logo': 'https://www.malaymail.com/graphics/meta/main/logo-310x150.png',
#                             'msvalidate.01': '380AB6648DCC03639FD185A152283333',
#                             'og:description': 'PUTRAJAYA, Sept 19 — The '
#                                               'government will not protect the '
#                                               'four Malaysian companies '
#                                               'alleged to have caused the '
#                                               'forest fires in Indonesia if '
#                                               'such claims are proven true, '
#                                               'said Primary Industries '
#                                               'Minister Teresa Kok today. As '
#                                               'Indonesia had not provided '
#                                               'concrete evidence with regard '
#                                               'to these claims, it...',
#                             'og:image': 'https://media.malaymail.com/resize_cache/uploads/articles/2019/2019-09/000_1KD08R-seo.jpg',
#                             'og:title': 'Kok: Malaysian companies won’t be '
#                                         'protected if Indonesian forest fire '
#                                         'claims are true | Malay Mail',
#                             'og:type': 'website',
#                             'og:url': 'https://www.malaymail.com/news/malaysia/2019/09/19/kok-malaysian-companies-wont-be-protected-if-indonesian-forest-fire-claims/1792209',
#                             'theme-color': '#ed0000',
#                             'twitter:card': 'summary_large_image',
#                             'twitter:creator': '@malaymail',
#                             'twitter:description': 'PUTRAJAYA, Sept 19 — The '
#                                                    'government will not '
#                                                    'protect the four Malaysian '
#                                                    'companies alleged to have '
#                                                    'caused the forest fires in '
#                                                    'Indonesia if such claims '
#                                                    'are proven true, said '
#                                                    'Primary Industries '
#                                                    'Minister Teresa Kok today. '
#                                                    'As Indonesia had not '
#                                                    'provided concrete evidence '
#                                                    'with regard to these '
#                                                    'claims, it...',
#                             'twitter:image': 'https://media.malaymail.com/resize_cache/uploads/articles/2019/2019-09/000_1KD08R-seo.jpg',
#                             'twitter:site': '@malaymail',
#                             'twitter:title': 'Kok: Malaysian companies won’t '
#                                              'be protected if Indonesian '
#                                              'forest fire claims are true | '
#                                              'Malay Mail',
#                             'twitter:url': 'https://www.malaymail.com/news/malaysia/2019/09/19/kok-malaysian-companies-wont-be-protected-if-indonesian-forest-fire-claims/1792209',
#                             'viewport': 'width=device-width, '
#                                         'initial-scale=1'}]},
#   'snippet': 'Sep 19, 2019 ... PUTRAJAYA, Sept 19 — The government will not '
#              'protect the four Malaysian \n'
#              'companies alleged to have caused the forest fires in Indonesia '
#              'if\xa0...',
#   'title': "Kok: Malaysian companies won't be protected if Indonesian forest "
#            '...'},
#  {'cacheId': 'cwfjambe5i8J',
#   'displayLink': 'www.malaymail.com',
#   'formattedUrl': 'https://www.malaymail.com/news/malaysia/...by-forest-fire/1791385',
#   'htmlFormattedUrl': 'https://www.malaymail.com/news/malaysia/...by-<b>forest</b>-<b>fire</b>/1791385',
#   'htmlSnippet': 'Sep 17, 2019 <b>...</b> TDM Bhd said the areas affected by '
#                  '<b>fire</b> are known as North 2 Estate at NB2-<br>\n'
#                  'Tapang ria, NB3-Kemantan, NB7-Kancing and NB8-Kayan.',
#   'htmlTitle': 'Malaysia&#39;s TDM Bhd confirms Indonesian unit affected by '
#                '<b>forest fire</b> ...',
#   'kind': 'customsearch#result',
#   'link': 'https://www.malaymail.com/news/malaysia/2019/09/17/malaysias-tdm-bhd-confirms-indonesian-unit-affected-by-forest-fire/1791385',
#   'pagemap': {'cse_image': [{'src': 'https://media.malaymail.com/resize_cache/uploads/articles/2019/2019-09/000_1K59X9-seo.jpg'}],
#               'cse_thumbnail': [{'height': '163',
#                                  'src': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcS8JEHlRpKbzk2kHdkw1DCgaC_BZDRsUBSNdvX3Ohb9hn32LC2bJsJrGwp9',
#                                  'width': '310'}],
#               'metatags': [{'dailymotion-domain-verification': 'dmo5qgk0uy3qakucb',
#                             'fb:app_id': '1709756459249190',
#                             'fb:pages': '163335377171805',
#                             'msapplication-square150x150logo': 'https://www.malaymail.com/graphics/meta/main/logo-150x150.png',
#                             'msapplication-wide310x150logo': 'https://www.malaymail.com/graphics/meta/main/logo-310x150.png',
#                             'msvalidate.01': '380AB6648DCC03639FD185A152283333',
#                             'og:description': 'KUALA LUMPUR, Sept 17 — '
#                                               'Approximately 1,201 hectares of '
#                                               'land owned by TDM Bhd’s unit, '
#                                               'PT Rafi Kamajaya Abadi (PTRKA), '
#                                               'has been affected by fire. In a '
#                                               'filing to Bursa Malaysia, TDM '
#                                               'said the areas are known as '
#                                               'North 2 Estate at NB2-Tapang '
#                                               'ria, NB3-Kemantan, NB7-Kancing '
#                                               'and NB8-Kayan. “From the...',
#                             'og:image': 'https://media.malaymail.com/resize_cache/uploads/articles/2019/2019-09/000_1K59X9-seo.jpg',
#                             'og:title': 'Malaysia’s TDM Bhd confirms '
#                                         'Indonesian unit affected by forest '
#                                         'fire | Malay Mail',
#                             'og:type': 'website',
#                             'og:url': 'https://www.malaymail.com/news/malaysia/2019/09/17/malaysias-tdm-bhd-confirms-indonesian-unit-affected-by-forest-fire/1791385',
#                             'theme-color': '#ed0000',
#                             'twitter:card': 'summary_large_image',
#                             'twitter:creator': '@malaymail',
#                             'twitter:description': 'KUALA LUMPUR, Sept 17 — '
#                                                    'Approximately 1,201 '
#                                                    'hectares of land owned by '
#                                                    'TDM Bhd’s unit, PT Rafi '
#                                                    'Kamajaya Abadi (PTRKA), '
#                                                    'has been affected by fire. '
#                                                    'In a filing to Bursa '
#                                                    'Malaysia, TDM said the '
#                                                    'areas are known as North 2 '
#                                                    'Estate at NB2-Tapang ria, '
#                                                    'NB3-Kemantan, NB7-Kancing '
#                                                    'and NB8-Kayan. “From '
#                                                    'the...',
#                             'twitter:image': 'https://media.malaymail.com/resize_cache/uploads/articles/2019/2019-09/000_1K59X9-seo.jpg',
#                             'twitter:site': '@malaymail',
#                             'twitter:title': 'Malaysia’s TDM Bhd confirms '
#                                              'Indonesian unit affected by '
#                                              'forest fire | Malay Mail',
#                             'twitter:url': 'https://www.malaymail.com/news/malaysia/2019/09/17/malaysias-tdm-bhd-confirms-indonesian-unit-affected-by-forest-fire/1791385',
#                             'viewport': 'width=device-width, '
#                                         'initial-scale=1'}]},
#   'snippet': 'Sep 17, 2019 ... TDM Bhd said the areas affected by fire are '
#              'known as North 2 Estate at NB2-\n'
#              'Tapang ria, NB3-Kemantan, NB7-Kancing and NB8-Kayan.',
#   'title': "Malaysia's TDM Bhd confirms Indonesian unit affected by forest "
#            'fire ...'},
#  {'cacheId': 'uKDzU7bWxPQJ',
#   'displayLink': 'www.malaymail.com',
#   'formattedUrl': 'https://www.malaymail.com/news/malaysia/...forest-fire/1828000',
#   'htmlFormattedUrl': 'https://www.malaymail.com/news/malaysia/...<b>forest</b>-<b>fire</b>/1828000',
#   'htmlSnippet': 'Jan 14, 2020 <b>...</b> It said the ministry, through the '
#                  'Peninsular Malaysia Forestry Department, is <br>\n'
#                  'always aware of <b>forest fires</b>, especially if they '
#                  'occurred in the&nbsp;...',
#   'htmlTitle': 'State governments, local authorities, land owners told to '
#                'prevent ...',
#   'kind': 'customsearch#result',
#   'link': 'https://www.malaymail.com/news/malaysia/2020/01/14/state-governments-local-authorities-land-owners-told-to-prevent-forest-fire/1828000',
#   'pagemap': {'cse_image': [{'src': 'https://media.malaymail.com/resize_cache/uploads/articles/2019/2019-08/johor_gelang_patah_fire_20190824-seo.jpeg'}],
#               'cse_thumbnail': [{'height': '163',
#                                  'src': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcRnkSLJC9izXNKYRxQkP1IRkff6J6Ags5D457vzNfcNBDkB0_-kXbk-hhs',
#                                  'width': '310'}],
#               'metatags': [{'dailymotion-domain-verification': 'dmo5qgk0uy3qakucb',
#                             'fb:app_id': '1709756459249190',
#                             'fb:pages': '163335377171805',
#                             'msapplication-square150x150logo': 'https://www.malaymail.com/graphics/meta/main/logo-150x150.png',
#                             'msapplication-wide310x150logo': 'https://www.malaymail.com/graphics/meta/main/logo-310x150.png',
#                             'msvalidate.01': '380AB6648DCC03639FD185A152283333',
#                             'og:description': 'KUALA LUMPUR, Jan 14 — State '
#                                               'governments, local authorities '
#                                               'and land owners are advised to '
#                                               'take appropriate measures to '
#                                               'prevent forest fire. Water, '
#                                               'Land and Natural Resources '
#                                               'Ministry (KATS), in a '
#                                               'statement, said they should '
#                                               'also take steps to prevent '
#                                               'irresponsible quarters from '
#                                               'trespassing into...',
#                             'og:image': 'https://media.malaymail.com/resize_cache/uploads/articles/2019/2019-08/johor_gelang_patah_fire_20190824-seo.jpeg',
#                             'og:title': 'State governments, local authorities, '
#                                         'land owners told to prevent forest '
#                                         'fire | Malay Mail',
#                             'og:type': 'website',
#                             'og:url': 'https://www.malaymail.com/news/malaysia/2020/01/14/state-governments-local-authorities-land-owners-told-to-prevent-forest-fire/1828000',
#                             'theme-color': '#ed0000',
#                             'twitter:card': 'summary_large_image',
#                             'twitter:creator': '@malaymail',
#                             'twitter:description': 'KUALA LUMPUR, Jan 14 — '
#                                                    'State governments, local '
#                                                    'authorities and land '
#                                                    'owners are advised to take '
#                                                    'appropriate measures to '
#                                                    'prevent forest fire. '
#                                                    'Water, Land and Natural '
#                                                    'Resources Ministry (KATS), '
#                                                    'in a statement, said they '
#                                                    'should also take steps to '
#                                                    'prevent irresponsible '
#                                                    'quarters from trespassing '
#                                                    'into...',
#                             'twitter:image': 'https://media.malaymail.com/resize_cache/uploads/articles/2019/2019-08/johor_gelang_patah_fire_20190824-seo.jpeg',
#                             'twitter:site': '@malaymail',
#                             'twitter:title': 'State governments, local '
#                                              'authorities, land owners told to '
#                                              'prevent forest fire | Malay Mail',
#                             'twitter:url': 'https://www.malaymail.com/news/malaysia/2020/01/14/state-governments-local-authorities-land-owners-told-to-prevent-forest-fire/1828000',
#                             'viewport': 'width=device-width, '
#                                         'initial-scale=1'}]},
#   'snippet': 'Jan 14, 2020 ... It said the ministry, through the Peninsular '
#              'Malaysia Forestry Department, is \n'
#              'always aware of forest fires, especially if they occurred in '
#              'the\xa0...',
#   'title': 'State governments, local authorities, land owners told to prevent '
#            '...'},
#  {'cacheId': 'B6BUUmkkcBUJ',
#   'displayLink': 'www.malaymail.com',
#   'formattedUrl': 'https://www.malaymail.com/news/malaysia/.../forest-fire-in.../1784116',
#   'htmlFormattedUrl': 'https://www.malaymail.com/news/malaysia/.../<b>forest</b>-<b>fire</b>-in.../1784116',
#   'htmlSnippet': 'Aug 25, 2019 <b>...</b> JOHOR BARU, Aug 25 — Strong winds '
#                  'over the past few days caused the <b>forest</b> <br>\n'
#                  '<b>fire</b> at Kampung Pekajang in Iskandar Puteri, near '
#                  'here,&nbsp;...',
#   'htmlTitle': '<b>Forest fire</b> in Iskandar Puteri spreads to 98 hectares | '
#                'Malaysia ...',
#   'kind': 'customsearch#result',
#   'link': 'https://www.malaymail.com/news/malaysia/2019/08/25/forest-fire-in-iskandar-puteri-spreads-to-98-hectares/1784116',
#   'pagemap': {'cse_image': [{'src': 'https://media.malaymail.com/resize_cache/uploads/articles/2019/2019-08/2508_forest_fire_iskandar_puteri_bernama-seo.jpg'}],
#               'cse_thumbnail': [{'height': '163',
#                                  'src': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcQVHab1_ePgbC58e7w-0sJ-c6HG-k9cYTHfJ7ZUaKwm-ydI8FIa5Xj2nx_f',
#                                  'width': '310'}],
#               'metatags': [{'dailymotion-domain-verification': 'dmo5qgk0uy3qakucb',
#                             'fb:app_id': '1709756459249190',
#                             'fb:pages': '163335377171805',
#                             'msapplication-square150x150logo': 'https://www.malaymail.com/graphics/meta/main/logo-150x150.png',
#                             'msapplication-wide310x150logo': 'https://www.malaymail.com/graphics/meta/main/logo-310x150.png',
#                             'msvalidate.01': '380AB6648DCC03639FD185A152283333',
#                             'og:description': 'JOHOR BARU, Aug 25&nbsp;— '
#                                               'Strong winds over the past few '
#                                               'days caused the forest fire at '
#                                               'Kampung Pekajang in Iskandar '
#                                               'Puteri, near here, to spread to '
#                                               'a new area of 98 hectares today '
#                                               'as opposed to just 16 hectares '
#                                               'on Friday. However, Johor Fire '
#                                               'and Rescue Department (JBPM) '
#                                               'director Datuk Yahaya...',
#                             'og:image': 'https://media.malaymail.com/resize_cache/uploads/articles/2019/2019-08/2508_forest_fire_iskandar_puteri_bernama-seo.jpg',
#                             'og:title': 'Forest fire in Iskandar Puteri '
#                                         'spreads to 98 hectares | Malay Mail',
#                             'og:type': 'website',
#                             'og:url': 'https://www.malaymail.com/news/malaysia/2019/08/25/forest-fire-in-iskandar-puteri-spreads-to-98-hectares/1784116',
#                             'theme-color': '#ed0000',
#                             'twitter:card': 'summary_large_image',
#                             'twitter:creator': '@malaymail',
#                             'twitter:description': 'JOHOR BARU, Aug 25&nbsp;— '
#                                                    'Strong winds over the past '
#                                                    'few days caused the forest '
#                                                    'fire at Kampung Pekajang '
#                                                    'in Iskandar Puteri, near '
#                                                    'here, to spread to a new '
#                                                    'area of 98 hectares today '
#                                                    'as opposed to just 16 '
#                                                    'hectares on Friday. '
#                                                    'However, Johor Fire and '
#                                                    'Rescue Department (JBPM) '
#                                                    'director Datuk Yahaya...',
#                             'twitter:image': 'https://media.malaymail.com/resize_cache/uploads/articles/2019/2019-08/2508_forest_fire_iskandar_puteri_bernama-seo.jpg',
#                             'twitter:site': '@malaymail',
#                             'twitter:title': 'Forest fire in Iskandar Puteri '
#                                              'spreads to 98 hectares | Malay '
#                                              'Mail',
#                             'twitter:url': 'https://www.malaymail.com/news/malaysia/2019/08/25/forest-fire-in-iskandar-puteri-spreads-to-98-hectares/1784116',
#                             'viewport': 'width=device-width, '
#                                         'initial-scale=1'}]},
#   'snippet': 'Aug 25, 2019 ... JOHOR BARU, Aug 25 — Strong winds over the past '
#              'few days caused the forest \n'
#              'fire at Kampung Pekajang in Iskandar Puteri, near here,\xa0...',
#   'title': 'Forest fire in Iskandar Puteri spreads to 98 hectares | Malaysia '
#            '...'},
#  {'cacheId': 'reIZPKYi0d4J',
#   'displayLink': 'www.malaymail.com',
#   'formattedUrl': 'https://www.malaymail.com/news/.../firefighters...forest-fire.../1783854',
#   'htmlFormattedUrl': 'https://www.malaymail.com/news/.../<b>fire</b>fighters...<b>forest</b>-<b>fire</b>.../1783854',
#   'htmlSnippet': 'Aug 24, 2019 <b>...</b> Firemen containing the secondary '
#                  '<b>forest fire</b> at Jalan Tanjung Kupang in <br>\n'
#                  'Kampung Pekajang, Gelang Patah today. — Picture courtesy of '
#                  'the&nbsp;...',
#   'htmlTitle': 'Firefighters say 60pc of Gelang Patah <b>forest fire</b> '
#                'contained ...',
#   'kind': 'customsearch#result',
#   'link': 'https://www.malaymail.com/news/malaysia/2019/08/24/firefighters-say-60pc-of-gelang-patah-forest-fire-contained/1783854',
#   'pagemap': {'cse_image': [{'src': 'https://media.malaymail.com/resize_cache/uploads/articles/2019/2019-08/johor_gelang_patah_fire_20190824-seo.jpeg'}],
#               'cse_thumbnail': [{'height': '163',
#                                  'src': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcRnkSLJC9izXNKYRxQkP1IRkff6J6Ags5D457vzNfcNBDkB0_-kXbk-hhs',
#                                  'width': '310'}],
#               'metatags': [{'dailymotion-domain-verification': 'dmo5qgk0uy3qakucb',
#                             'fb:app_id': '1709756459249190',
#                             'fb:pages': '163335377171805',
#                             'msapplication-square150x150logo': 'https://www.malaymail.com/graphics/meta/main/logo-150x150.png',
#                             'msapplication-wide310x150logo': 'https://www.malaymail.com/graphics/meta/main/logo-310x150.png',
#                             'msvalidate.01': '380AB6648DCC03639FD185A152283333',
#                             'og:description': 'ISKANDAR PUTERI, Aug 24 — '
#                                               'Firemen today have managed to '
#                                               'contain about 60 per cent of '
#                                               'the fire spanning more than 16 '
#                                               'hectares of secondary forest at '
#                                               'Gelang Patah that has been '
#                                               'ablaze for several days. Parts '
#                                               'of a secondary forest at Jalan '
#                                               'Tanjung Kupang in Kampung '
#                                               'Pekajang, Gelang Patah here '
#                                               'were...',
#                             'og:image': 'https://media.malaymail.com/resize_cache/uploads/articles/2019/2019-08/johor_gelang_patah_fire_20190824-seo.jpeg',
#                             'og:title': 'Firefighters say 60pc of Gelang Patah '
#                                         'forest fire contained | Malay Mail',
#                             'og:type': 'website',
#                             'og:url': 'https://www.malaymail.com/news/malaysia/2019/08/24/firefighters-say-60pc-of-gelang-patah-forest-fire-contained/1783854',
#                             'theme-color': '#ed0000',
#                             'twitter:card': 'summary_large_image',
#                             'twitter:creator': '@malaymail',
#                             'twitter:description': 'ISKANDAR PUTERI, Aug 24 — '
#                                                    'Firemen today have managed '
#                                                    'to contain about 60 per '
#                                                    'cent of the fire spanning '
#                                                    'more than 16 hectares of '
#                                                    'secondary forest at Gelang '
#                                                    'Patah that has been ablaze '
#                                                    'for several days. Parts of '
#                                                    'a secondary forest at '
#                                                    'Jalan Tanjung Kupang in '
#                                                    'Kampung Pekajang, Gelang '
#                                                    'Patah here were...',
#                             'twitter:image': 'https://media.malaymail.com/resize_cache/uploads/articles/2019/2019-08/johor_gelang_patah_fire_20190824-seo.jpeg',
#                             'twitter:site': '@malaymail',
#                             'twitter:title': 'Firefighters say 60pc of Gelang '
#                                              'Patah forest fire contained | '
#                                              'Malay Mail',
#                             'twitter:url': 'https://www.malaymail.com/news/malaysia/2019/08/24/firefighters-say-60pc-of-gelang-patah-forest-fire-contained/1783854',
#                             'viewport': 'width=device-width, '
#                                         'initial-scale=1'}]},
#   'snippet': 'Aug 24, 2019 ... Firemen containing the secondary forest fire at '
#              'Jalan Tanjung Kupang in \n'
#              'Kampung Pekajang, Gelang Patah today. — Picture courtesy of '
#              'the\xa0...',
#   'title': 'Firefighters say 60pc of Gelang Patah forest fire contained ...'},
#  {'cacheId': 'hVErn8TrM3wJ',
#   'displayLink': 'www.malaymail.com',
#   'formattedUrl': 'https://www.malaymail.com/news/malaysia/...forest-fire.../1784410',
#   'htmlFormattedUrl': 'https://www.malaymail.com/news/malaysia/...<b>forest</b>-<b>fire</b>.../1784410',
#   'htmlSnippet': 'Aug 26, 2019 <b>...</b> JOHOR BARU, Aug 26 — The 16-hectare '
#                  '<b>forest fire</b> in Kampung Pekajang, <br>\n'
#                  'Gelang Patah, near here, reported to have been burning '
#                  'since&nbsp;...',
#   'htmlTitle': 'Johor MB: Gelang Patah <b>forest fire</b> involves privately '
#                'owned ...',
#   'kind': 'customsearch#result',
#   'link': 'https://www.malaymail.com/news/malaysia/2019/08/26/johor-mb-gelang-patah-forest-fire-involves-privately-owned-agricultural-lan/1784410',
#   'pagemap': {'cse_image': [{'src': 'https://media.malaymail.com/resize_cache/uploads/articles/2019/2019-08/johor_gelang_patah_fire_20190824-seo.jpeg'}],
#               'cse_thumbnail': [{'height': '163',
#                                  'src': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcRnkSLJC9izXNKYRxQkP1IRkff6J6Ags5D457vzNfcNBDkB0_-kXbk-hhs',
#                                  'width': '310'}],
#               'metatags': [{'dailymotion-domain-verification': 'dmo5qgk0uy3qakucb',
#                             'fb:app_id': '1709756459249190',
#                             'fb:pages': '163335377171805',
#                             'msapplication-square150x150logo': 'https://www.malaymail.com/graphics/meta/main/logo-150x150.png',
#                             'msapplication-wide310x150logo': 'https://www.malaymail.com/graphics/meta/main/logo-310x150.png',
#                             'msvalidate.01': '380AB6648DCC03639FD185A152283333',
#                             'og:description': 'JOHOR BARU, Aug 26 — The '
#                                               '16-hectare forest fire in '
#                                               'Kampung Pekajang, Gelang Patah, '
#                                               'near here, reported to have '
#                                               'been burning since Wednesday, '
#                                               'involved privately owned '
#                                               'agricultural land. Johor Mentri '
#                                               'Besar Datuk Dr Sahruddin Jamal '
#                                               'said a survey found the fire, '
#                                               '60 per cent of which has '
#                                               'been...',
#                             'og:image': 'https://media.malaymail.com/resize_cache/uploads/articles/2019/2019-08/johor_gelang_patah_fire_20190824-seo.jpeg',
#                             'og:title': 'Johor MB: Gelang Patah forest fire '
#                                         'involves privately owned agricultural '
#                                         'land | Malay Mail',
#                             'og:type': 'website',
#                             'og:url': 'https://www.malaymail.com/news/malaysia/2019/08/26/johor-mb-gelang-patah-forest-fire-involves-privately-owned-agricultural-lan/1784410',
#                             'theme-color': '#ed0000',
#                             'twitter:card': 'summary_large_image',
#                             'twitter:creator': '@malaymail',
#                             'twitter:description': 'JOHOR BARU, Aug 26 — The '
#                                                    '16-hectare forest fire in '
#                                                    'Kampung Pekajang, Gelang '
#                                                    'Patah, near here, reported '
#                                                    'to have been burning since '
#                                                    'Wednesday, involved '
#                                                    'privately owned '
#                                                    'agricultural land. Johor '
#                                                    'Mentri Besar Datuk Dr '
#                                                    'Sahruddin Jamal said a '
#                                                    'survey found the fire, 60 '
#                                                    'per cent of which has '
#                                                    'been...',
#                             'twitter:image': 'https://media.malaymail.com/resize_cache/uploads/articles/2019/2019-08/johor_gelang_patah_fire_20190824-seo.jpeg',
#                             'twitter:site': '@malaymail',
#                             'twitter:title': 'Johor MB: Gelang Patah forest '
#                                              'fire involves privately owned '
#                                              'agricultural land | Malay Mail',
#                             'twitter:url': 'https://www.malaymail.com/news/malaysia/2019/08/26/johor-mb-gelang-patah-forest-fire-involves-privately-owned-agricultural-lan/1784410',
#                             'viewport': 'width=device-width, '
#                                         'initial-scale=1'}]},
#   'snippet': 'Aug 26, 2019 ... JOHOR BARU, Aug 26 — The 16-hectare forest fire '
#              'in Kampung Pekajang, \n'
#              'Gelang Patah, near here, reported to have been burning since\xa0'
#              '...',
#   'title': 'Johor MB: Gelang Patah forest fire involves privately owned ...'},
#  {'cacheId': 'MMtCPdsIyIkJ',
#   'displayLink': 'www.malaymail.com',
#   'formattedUrl': 'https://www.malaymail.com/news/malaysia/...forest-fire.../1784793',
#   'htmlFormattedUrl': 'https://www.malaymail.com/news/malaysia/...<b>forest</b>-<b>fire</b>.../1784793',
#   'htmlSnippet': 'Aug 27, 2019 <b>...</b> JOHOR BARU, Aug 27 — Two schools '
#                  'that were closed for two days due to a <br>\n'
#                  '<b>forest fire</b> in Gelang Patah will reopen and resume '
#                  'classes&nbsp;...',
#   'htmlTitle': 'Johor schools closed due to <b>forest fire</b> to reopen '
#                'tomorrow, says ...',
#   'kind': 'customsearch#result',
#   'link': 'https://www.malaymail.com/news/malaysia/2019/08/27/johor-schools-closed-due-to-forest-fire-to-reopen-tomorrow-says-state-educa/1784793',
#   'pagemap': {'cse_image': [{'src': 'https://media.malaymail.com/resize_cache/uploads/articles/2019/2019-08/johor_gelang_patah_fire_20190824-seo.jpeg'}],
#               'cse_thumbnail': [{'height': '163',
#                                  'src': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcRnkSLJC9izXNKYRxQkP1IRkff6J6Ags5D457vzNfcNBDkB0_-kXbk-hhs',
#                                  'width': '310'}],
#               'metatags': [{'dailymotion-domain-verification': 'dmo5qgk0uy3qakucb',
#                             'fb:app_id': '1709756459249190',
#                             'fb:pages': '163335377171805',
#                             'msapplication-square150x150logo': 'https://www.malaymail.com/graphics/meta/main/logo-150x150.png',
#                             'msapplication-wide310x150logo': 'https://www.malaymail.com/graphics/meta/main/logo-310x150.png',
#                             'msvalidate.01': '380AB6648DCC03639FD185A152283333',
#                             'og:description': 'JOHOR BARU, Aug 27 — Two '
#                                               'schools that were closed for '
#                                               'two days due to a forest fire '
#                                               'in Gelang Patah will reopen and '
#                                               'resume classes tomorrow, said '
#                                               'Johor Education Department '
#                                               'deputy director (school '
#                                               'management) Ab Rahim Lamin. He '
#                                               'said the decision to reopen SK '
#                                               'Tanjung Adang and SMK Tanjung '
#                                               'Adang...',
#                             'og:image': 'https://media.malaymail.com/resize_cache/uploads/articles/2019/2019-08/johor_gelang_patah_fire_20190824-seo.jpeg',
#                             'og:title': 'Johor schools closed due to forest '
#                                         'fire to reopen tomorrow, says state '
#                                         'education dept | Malay Mail',
#                             'og:type': 'website',
#                             'og:url': 'https://www.malaymail.com/news/malaysia/2019/08/27/johor-schools-closed-due-to-forest-fire-to-reopen-tomorrow-says-state-educa/1784793',
#                             'theme-color': '#ed0000',
#                             'twitter:card': 'summary_large_image',
#                             'twitter:creator': '@malaymail',
#                             'twitter:description': 'JOHOR BARU, Aug 27 — Two '
#                                                    'schools that were closed '
#                                                    'for two days due to a '
#                                                    'forest fire in Gelang '
#                                                    'Patah will reopen and '
#                                                    'resume classes tomorrow, '
#                                                    'said Johor Education '
#                                                    'Department deputy director '
#                                                    '(school management) Ab '
#                                                    'Rahim Lamin. He said the '
#                                                    'decision to reopen SK '
#                                                    'Tanjung Adang and SMK '
#                                                    'Tanjung Adang...',
#                             'twitter:image': 'https://media.malaymail.com/resize_cache/uploads/articles/2019/2019-08/johor_gelang_patah_fire_20190824-seo.jpeg',
#                             'twitter:site': '@malaymail',
#                             'twitter:title': 'Johor schools closed due to '
#                                              'forest fire to reopen tomorrow, '
#                                              'says state education dept | '
#                                              'Malay Mail',
#                             'twitter:url': 'https://www.malaymail.com/news/malaysia/2019/08/27/johor-schools-closed-due-to-forest-fire-to-reopen-tomorrow-says-state-educa/1784793',
#                             'viewport': 'width=device-width, '
#                                         'initial-scale=1'}]},
#   'snippet': 'Aug 27, 2019 ... JOHOR BARU, Aug 27 — Two schools that were '
#              'closed for two days due to a \n'
#              'forest fire in Gelang Patah will reopen and resume classes\xa0'
#              '...',
#   'title': 'Johor schools closed due to forest fire to reopen tomorrow, says '
#            '...'},
#  {'cacheId': 'rdEybFRTqmsJ',
#   'displayLink': 'www.malaymail.com',
#   'formattedUrl': 'https://www.malaymail.com/news/world/2019/.../forest-fire.../1792508',
#   'htmlFormattedUrl': 'https://www.malaymail.com/news/world/2019/.../<b>forest</b>-<b>fire</b>.../1792508',
#   'htmlSnippet': 'Sep 20, 2019 <b>...</b> SINGAPORE, Sept 20 — Singapore&#39;s '
#                  'skies were clearer today and air quality <br>\n'
#                  'improved as smog from Indonesian <b>forest fires</b> drifted '
#                  'away,&nbsp;...',
#   'htmlTitle': '<b>Forest fire</b> haze clears over Singapore ahead of F1 | '
#                'World | Malay ...',
#   'kind': 'customsearch#result',
#   'link': 'https://www.malaymail.com/news/world/2019/09/20/forest-fire-haze-clears-over-singapore-ahead-of-f1/1792508',
#   'pagemap': {'cse_image': [{'src': 'https://media.malaymail.com/resize_cache/uploads/articles/2019/2019-09/singapore_Grand_Prix_track_200919-seo.jpg'}],
#               'cse_thumbnail': [{'height': '163',
#                                  'src': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcS_roDJdqW0MHukCwNIGoAkzjDLzFIdF5402F_tz958qoAao3FGpB_LIjxa',
#                                  'width': '310'}],
#               'metatags': [{'dailymotion-domain-verification': 'dmo5qgk0uy3qakucb',
#                             'fb:app_id': '1709756459249190',
#                             'fb:pages': '163335377171805',
#                             'msapplication-square150x150logo': 'https://www.malaymail.com/graphics/meta/main/logo-150x150.png',
#                             'msapplication-wide310x150logo': 'https://www.malaymail.com/graphics/meta/main/logo-310x150.png',
#                             'msvalidate.01': '380AB6648DCC03639FD185A152283333',
#                             'og:description': 'SINGAPORE, Sept 20 — '
#                                               'Singapore’s skies were clearer '
#                                               'today and air quality improved '
#                                               'as smog from Indonesian forest '
#                                               'fires drifted away, easing '
#                                               'fears that this weekend’s '
#                                               'Formula One race may be '
#                                               'affected. Raging blazes in '
#                                               'Indonesia have been spewing '
#                                               'toxic haze over neighbouring '
#                                               'Singapore and...',
#                             'og:image': 'https://media.malaymail.com/resize_cache/uploads/articles/2019/2019-09/singapore_Grand_Prix_track_200919-seo.jpg',
#                             'og:title': 'Forest fire haze clears over '
#                                         'Singapore ahead of F1 | Malay Mail',
#                             'og:type': 'website',
#                             'og:url': 'https://www.malaymail.com/news/world/2019/09/20/forest-fire-haze-clears-over-singapore-ahead-of-f1/1792508',
#                             'theme-color': '#ed0000',
#                             'twitter:card': 'summary_large_image',
#                             'twitter:creator': '@malaymail',
#                             'twitter:description': 'SINGAPORE, Sept 20 — '
#                                                    'Singapore’s skies were '
#                                                    'clearer today and air '
#                                                    'quality improved as smog '
#                                                    'from Indonesian forest '
#                                                    'fires drifted away, easing '
#                                                    'fears that this weekend’s '
#                                                    'Formula One race may be '
#                                                    'affected. Raging blazes in '
#                                                    'Indonesia have been '
#                                                    'spewing toxic haze over '
#                                                    'neighbouring Singapore '
#                                                    'and...',
#                             'twitter:image': 'https://media.malaymail.com/resize_cache/uploads/articles/2019/2019-09/singapore_Grand_Prix_track_200919-seo.jpg',
#                             'twitter:site': '@malaymail',
#                             'twitter:title': 'Forest fire haze clears over '
#                                              'Singapore ahead of F1 | Malay '
#                                              'Mail',
#                             'twitter:url': 'https://www.malaymail.com/news/world/2019/09/20/forest-fire-haze-clears-over-singapore-ahead-of-f1/1792508',
#                             'viewport': 'width=device-width, '
#                                         'initial-scale=1'}]},
#   'snippet': "Sep 20, 2019 ... SINGAPORE, Sept 20 — Singapore's skies were "
#              'clearer today and air quality \n'
#              'improved as smog from Indonesian forest fires drifted away,\xa0'
#              '...',
#   'title': 'Forest fire haze clears over Singapore ahead of F1 | World | Malay '
#            '...'},
#  {'cacheId': '8m8L8m5Fq4UJ',
#   'displayLink': 'www.malaymail.com',
#   'formattedUrl': 'https://www.malaymail.com/news/malaysia/...forest-fire-in.../1781472',
#   'htmlFormattedUrl': 'https://www.malaymail.com/news/malaysia/...<b>forest</b>-<b>fire</b>-in.../1781472',
#   'htmlSnippet': 'Aug 16, 2019 <b>...</b> MIRI, Aug 16 — A total of 198000 '
#                  'litres of water was used to fight a <b>forest fire</b> in '
#                  '<br>\n'
#                  'Kuala Baram today. Malaysian Maritime Enforcement '
#                  'Agency&nbsp;...',
#   'htmlTitle': 'MMEA uses 198,000 litres of water to fight <b>forest fire</b> '
#                'in Miri ...',
#   'kind': 'customsearch#result',
#   'link': 'https://www.malaymail.com/news/malaysia/2019/08/16/mmea-uses-198000-litres-of-water-to-fight-forest-fire-in-miri/1781472',
#   'pagemap': {'cse_image': [{'src': 'https://media.malaymail.com/resize_cache/uploads/articles/2019/2019-08/FW922337_SK09_140819_APMM_PESAWAT-lpr-seo.jpg'}],
#               'cse_thumbnail': [{'height': '163',
#                                  'src': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcTNqyDoA1sgq1vRUdXria_QoTB90-eq5TUuR5QVBefkyg-2Ds1zSOQYJkke',
#                                  'width': '310'}],
#               'metatags': [{'dailymotion-domain-verification': 'dmo5qgk0uy3qakucb',
#                             'fb:app_id': '1709756459249190',
#                             'fb:pages': '163335377171805',
#                             'msapplication-square150x150logo': 'https://www.malaymail.com/graphics/meta/main/logo-150x150.png',
#                             'msapplication-wide310x150logo': 'https://www.malaymail.com/graphics/meta/main/logo-310x150.png',
#                             'msvalidate.01': '380AB6648DCC03639FD185A152283333',
#                             'og:description': 'MIRI, Aug 16 —&nbsp; A total of '
#                                               '198,000 litres of water was '
#                                               'used&nbsp; to fight a forest '
#                                               'fire in Kuala Baram today. '
#                                               'Malaysian Maritime Enforcement '
#                                               'Agency (MMEA) Sarawak director '
#                                               'First Admiral Robert Teh Geok '
#                                               'Chuan said two flights, using '
#                                               'the Bombardier CL415 aircraft, '
#                                               'were carried out by the...',
#                             'og:image': 'https://media.malaymail.com/resize_cache/uploads/articles/2019/2019-08/FW922337_SK09_140819_APMM_PESAWAT-lpr-seo.jpg',
#                             'og:title': 'MMEA uses 198,000 litres of water to '
#                                         'fight forest fire in Miri | Malay '
#                                         'Mail',
#                             'og:type': 'website',
#                             'og:url': 'https://www.malaymail.com/news/malaysia/2019/08/16/mmea-uses-198000-litres-of-water-to-fight-forest-fire-in-miri/1781472',
#                             'theme-color': '#ed0000',
#                             'twitter:card': 'summary_large_image',
#                             'twitter:creator': '@malaymail',
#                             'twitter:description': 'MIRI, Aug 16 —&nbsp; A '
#                                                    'total of 198,000 litres of '
#                                                    'water was used&nbsp; to '
#                                                    'fight a forest fire in '
#                                                    'Kuala Baram today. '
#                                                    'Malaysian Maritime '
#                                                    'Enforcement Agency (MMEA) '
#                                                    'Sarawak director First '
#                                                    'Admiral Robert Teh Geok '
#                                                    'Chuan said two flights, '
#                                                    'using the Bombardier CL415 '
#                                                    'aircraft, were carried out '
#                                                    'by the...',
#                             'twitter:image': 'https://media.malaymail.com/resize_cache/uploads/articles/2019/2019-08/FW922337_SK09_140819_APMM_PESAWAT-lpr-seo.jpg',
#                             'twitter:site': '@malaymail',
#                             'twitter:title': 'MMEA uses 198,000 litres of '
#                                              'water to fight forest fire in '
#                                              'Miri | Malay Mail',
#                             'twitter:url': 'https://www.malaymail.com/news/malaysia/2019/08/16/mmea-uses-198000-litres-of-water-to-fight-forest-fire-in-miri/1781472',
#                             'viewport': 'width=device-width, '
#                                         'initial-scale=1'}]},
# ...
#   'snippet': 'Jul 27, 2018 ... The Cranston Fire was one of several wildland '
#              'blazes that erupted on \n'
#              'Wednesday in Riverside County, east of the city of Hemet, that '
#              'authorities\xa0...',
#   'title': 'Thousands flee wildfire burning near California mountain towns '
#            '...'},
#  {'cacheId': 'WPQQy6AgICcJ',
#   'displayLink': 'www.malaymail.com',
#   'formattedUrl': 'https://www.malaymail.com/.../only-the-brave-honors-heroes-of-deadly- '
#                   'yarnell-fire',
#   'htmlFormattedUrl': 'https://www.malaymail.com/.../only-the-brave-honors-heroes-of-deadly- '
#                       'yarnell-<b>fire</b>',
#   'htmlSnippet': 'Oct 14, 2017 <b>...</b> Hotshots, the country&#39;s top '
#                  '<b>wildland</b> firefighters, don&#39;t carry water, instead '
#                  'literally <br>\n'
#                  'fighting <b>fire</b> with <b>fire</b>, using chainsaws to '
#                  'fell trees and burn&nbsp;...',
#   'htmlTitle': '&#39;Only the Brave&#39; honours heroes of deadly Yarnell '
#                '<b>fire</b> | Showbiz ...',
#   'kind': 'customsearch#result',
#   'link': 'https://www.malaymail.com/showbiz/article/only-the-brave-honors-heroes-of-deadly-yarnell-fire',
#   'pagemap': {'cse_image': [{'src': 'https://media.malaymail.com/resize_cache/uploads/blurbs/2017/2017-10/only_the_brave_051017-seo.jpg'}],
#               'metatags': [{'dailymotion-domain-verification': 'dmo5qgk0uy3qakucb',
#                             'fb:app_id': '1709756459249190',
#                             'fb:pages': '163335377171805',
#                             'msapplication-square150x150logo': 'https://www.malaymail.com/graphics/meta/main/logo-150x150.png',
#                             'msapplication-wide310x150logo': 'https://www.malaymail.com/graphics/meta/main/logo-310x150.png',
#                             'msvalidate.01': '380AB6648DCC03639FD185A152283333',
#                             'og:description': 'LOS ANGELES, Oct 14 — On a '
#                                               'blistering June morning in '
#                                               '2013, Arizona’s Granite '
#                                               'Mountain Hotshots elite '
#                                               'firefighting squad went into '
#                                               'the wilderness to protect the '
#                                               'town of Yarnell from a '
#                                               'ferocious blaze.&nbsp; By the '
#                                               'end of the day, all but one of '
#                                               'the 20 man crew were '
#                                               'dead.&nbsp; It was the...',
#                             'og:image': 'https://media.malaymail.com/resize_cache/uploads/blurbs/2017/2017-10/only_the_brave_051017-seo.jpg',
#                             'og:title': '‘Only the Brave’ honours heroes of '
#                                         'deadly Yarnell fire | Malay Mail',
#                             'og:type': 'website',
#                             'og:url': 'https://www.malaymail.com/news/showbiz/2017/10/14/only-the-brave-honors-heroes-of-deadly-yarnell-fire/1486985',
#                             'theme-color': '#ed0000',
#                             'twitter:card': 'summary_large_image',
#                             'twitter:creator': '@malaymail',
#                             'twitter:description': 'LOS ANGELES, Oct 14 — On a '
#                                                    'blistering June morning in '
#                                                    '2013, Arizona’s Granite '
#                                                    'Mountain Hotshots elite '
#                                                    'firefighting squad went '
#                                                    'into the wilderness to '
#                                                    'protect the town of '
#                                                    'Yarnell from a ferocious '
#                                                    'blaze.&nbsp; By the end of '
#                                                    'the day, all but one of '
#                                                    'the 20 man crew were '
#                                                    'dead.&nbsp; It was the...',
#                             'twitter:image': 'https://media.malaymail.com/resize_cache/uploads/blurbs/2017/2017-10/only_the_brave_051017-seo.jpg',
#                             'twitter:site': '@malaymail',
#                             'twitter:title': '‘Only the Brave’ honours heroes '
#                                              'of deadly Yarnell fire | Malay '
#                                              'Mail',
#                             'twitter:url': 'https://www.malaymail.com/news/showbiz/2017/10/14/only-the-brave-honors-heroes-of-deadly-yarnell-fire/1486985',
#                             'viewport': 'width=device-width, '
#                                         'initial-scale=1'}]},
#   'snippet': "Oct 14, 2017 ... Hotshots, the country's top wildland "
#              "firefighters, don't carry water, instead literally \n"
#              'fighting fire with fire, using chainsaws to fell trees and '
#              'burn\xa0...',
#   'title': "'Only the Brave' honours heroes of deadly Yarnell fire | Showbiz "
#            '...'},
#  {'cacheId': 'HP_SOWci954J',
#   'displayLink': 'www.malaymail.com',
#   'formattedUrl': 'https://www.malaymail.com/s/.../californias-deadliest-wildfire-finally-tamed',
#   'htmlFormattedUrl': 'https://www.malaymail.com/s/.../californias-deadliest-wild<b>fire</b>-finally-tamed',
#   'htmlSnippet': 'Nov 26, 2018 <b>...</b> LOS ANGELES, Nov 26 — The deadliest '
#                  'and most destructive <b>fire</b> in ... to as the <br>\n'
#                  '<b>wildland</b>-urban interface, where houses and '
#                  '<b>forest</b> vegetation&nbsp;...',
#   'htmlTitle': 'California&#39;s deadliest wildfire finally tamed | World | '
#                'Malay Mail',
#   'kind': 'customsearch#result',
#   'link': 'https://www.malaymail.com/s/1697013/californias-deadliest-wildfire-finally-tamed',
#   'pagemap': {'cse_image': [{'src': 'https://media.malaymail.com/resize_cache/uploads/articles/2018/2018-11/Irma_Corona_Gerryann_Wulbern_Camp_Fire_2611s-seo.JPG'}],
#               'cse_thumbnail': [{'height': '163',
#                                  'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTLrbzOhPU5PMj3YJIPGHEcxbKnFrLv8KxSEg5oSc8RR-84ZHejLWSJNIIw',
#                                  'width': '310'}],
#               'metatags': [{'dailymotion-domain-verification': 'dmo5qgk0uy3qakucb',
#                             'fb:app_id': '1709756459249190',
#                             'fb:pages': '163335377171805',
#                             'msapplication-square150x150logo': 'https://www.malaymail.com/graphics/meta/main/logo-150x150.png',
#                             'msapplication-wide310x150logo': 'https://www.malaymail.com/graphics/meta/main/logo-310x150.png',
#                             'msvalidate.01': '380AB6648DCC03639FD185A152283333',
#                             'og:description': 'LOS ANGELES, Nov 26 — The '
#                                               'deadliest and most destructive '
#                                               'fire in California’s history '
#                                               'was finally brought totally '
#                                               'under control by firefighters, '
#                                               'more than two weeks after it '
#                                               'erupted, authorities said '
#                                               'yesterday. “#CampFire ... is '
#                                               'now 100 per cent contained,” '
#                                               'Cal Fire, the state fire...',
#                             'og:image': 'https://media.malaymail.com/resize_cache/uploads/articles/2018/2018-11/Irma_Corona_Gerryann_Wulbern_Camp_Fire_2611s-seo.JPG',
#                             'og:title': 'California’s deadliest wildfire '
#                                         'finally tamed | Malay Mail',
#                             'og:type': 'website',
#                             'og:url': 'https://www.malaymail.com/news/world/2018/11/26/californias-deadliest-wildfire-finally-tamed/1697013',
#                             'theme-color': '#ed0000',
#                             'twitter:card': 'summary_large_image',
#                             'twitter:creator': '@malaymail',
#                             'twitter:description': 'LOS ANGELES, Nov 26 — The '
#                                                    'deadliest and most '
#                                                    'destructive fire in '
#                                                    'California’s history was '
#                                                    'finally brought totally '
#                                                    'under control by '
#                                                    'firefighters, more than '
#                                                    'two weeks after it '
#                                                    'erupted, authorities said '
#                                                    'yesterday. “#CampFire ... '
#                                                    'is now 100 per cent '
#                                                    'contained,” Cal Fire, the '
#                                                    'state fire...',
#                             'twitter:image': 'https://media.malaymail.com/resize_cache/uploads/articles/2018/2018-11/Irma_Corona_Gerryann_Wulbern_Camp_Fire_2611s-seo.JPG',
#                             'twitter:site': '@malaymail',
#                             'twitter:title': 'California’s deadliest wildfire '
#                                              'finally tamed | Malay Mail',
#                             'twitter:url': 'https://www.malaymail.com/news/world/2018/11/26/californias-deadliest-wildfire-finally-tamed/1697013',
#                             'viewport': 'width=device-width, '
#                                         'initial-scale=1'}]},
#   'snippet': 'Nov 26, 2018 ... LOS ANGELES, Nov 26 — The deadliest and most '
#              'destructive fire in ... to as the \n'
#              'wildland-urban interface, where houses and forest vegetation\xa0'
#              '...',
#   'title': "California's deadliest wildfire finally tamed | World | Malay "
#            'Mail'},
#  {'cacheId': 'lJvZk34eJRwJ',
#   'displayLink': 'www.malaymail.com',
#   'formattedUrl': 'https://www.malaymail.com/news/world/...it...wildfires...fire.../1785149',
#   'htmlFormattedUrl': 'https://www.malaymail.com/news/world/...it...wild<b>fires</b>...<b>fire</b>.../1785149',
#   'htmlSnippet': 'Aug 28, 2019 <b>...</b> Except this <b>fire</b> was '
#                  'deliberately set by state penitentiary. ... pine '
#                  '<b>forest</b> ablaze in <br>\n'
#                  'the mountains of New Mexico filling the air with thick, '
#                  'aromatic&nbsp;...',
#   'htmlTitle': 'Let it burn: US fights wildfires with <b>fire</b>, backed by '
#                'Trump | World ...',
#   'kind': 'customsearch#result',
#   'link': 'https://www.malaymail.com/news/world/2019/08/28/let-it-burn-us-fights-wildfires-with-fire-backed-by-trump/1785149',
#   'pagemap': {'cse_image': [{'src': 'https://media.malaymail.com/resize_cache/uploads/articles/2015-07/california_wildfire_20150718-seo.JPG'}],
#               'cse_thumbnail': [{'height': '163',
#                                  'src': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcSOwq52Tbt6mBOF3IjOdlndw1ZidOtcqZ78oEsvZfxszIwSfd59gDGa2_U',
#                                  'width': '310'}],
#               'metatags': [{'dailymotion-domain-verification': 'dmo5qgk0uy3qakucb',
#                             'fb:app_id': '1709756459249190',
#                             'fb:pages': '163335377171805',
#                             'msapplication-square150x150logo': 'https://www.malaymail.com/graphics/meta/main/logo-150x150.png',
#                             'msapplication-wide310x150logo': 'https://www.malaymail.com/graphics/meta/main/logo-310x150.png',
#                             'msvalidate.01': '380AB6648DCC03639FD185A152283333',
#                             'og:description': 'COYOTE, Aug 28 — It was the '
#                                               'kind of fire that has terrified '
#                                               'communities across the '
#                                               'drought-ridden US West in the '
#                                               'past few years: a ponderosa '
#                                               'pine forest ablaze in the '
#                                               'mountains of New Mexico filling '
#                                               'the air with thick, aromatic '
#                                               'smoke. Except this fire was '
#                                               'deliberately set by state '
#                                               'penitentiary...',
#                             'og:image': 'https://media.malaymail.com/resize_cache/uploads/articles/2015-07/california_wildfire_20150718-seo.JPG',
#                             'og:title': 'Let it burn: US fights wildfires with '
#                                         'fire, backed by Trump | Malay Mail',
#                             'og:type': 'website',
#                             'og:url': 'https://www.malaymail.com/news/world/2019/08/28/let-it-burn-us-fights-wildfires-with-fire-backed-by-trump/1785149',
#                             'theme-color': '#ed0000',
#                             'twitter:card': 'summary_large_image',
#                             'twitter:creator': '@malaymail',
#                             'twitter:description': 'COYOTE, Aug 28 — It was '
#                                                    'the kind of fire that has '
#                                                    'terrified communities '
#                                                    'across the drought-ridden '
#                                                    'US West in the past few '
#                                                    'years: a ponderosa pine '
#                                                    'forest ablaze in the '
#                                                    'mountains of New Mexico '
#                                                    'filling the air with '
#                                                    'thick, aromatic smoke. '
#                                                    'Except this fire was '
#                                                    'deliberately set by state '
#                                                    'penitentiary...',
#                             'twitter:image': 'https://media.malaymail.com/resize_cache/uploads/articles/2015-07/california_wildfire_20150718-seo.JPG',
#                             'twitter:site': '@malaymail',
#                             'twitter:title': 'Let it burn: US fights wildfires '
#                                              'with fire, backed by Trump | '
#                                              'Malay Mail',
#                             'twitter:url': 'https://www.malaymail.com/news/world/2019/08/28/let-it-burn-us-fights-wildfires-with-fire-backed-by-trump/1785149',
#                             'viewport': 'width=device-width, '
#                                         'initial-scale=1'}]},
#   'snippet': 'Aug 28, 2019 ... Except this fire was deliberately set by state '
#              'penitentiary. ... pine forest ablaze in \n'
#              'the mountains of New Mexico filling the air with thick, '
#              'aromatic\xa0...',
#   'title': 'Let it burn: US fights wildfires with fire, backed by Trump | '
#            'World ...'}]

# %%
# Prepare an array to pass the relevant links to a Pandas dataframe
for_df = []

# Filter only LinkedIn results
for name in range(len(results)) :
    for hits in range(len(results[name])) :
        if "burn" in results[name][hits]["link"] :
            for_df.append(results[name][hits])

df = pd.DataFrame(for_df)
df
# Out:
#                   kind                                              title  \
# 0  customsearch#result  Two bodies found in area burned by California ...
# 1  customsearch#result  Thousands flee wildfire burning near Californi...
# 2  customsearch#result  Let it burn: US fights wildfires with fire, ba...
# 3  customsearch#result  Two bodies found in area burned by California ...
# 4  customsearch#result  Thousands flee wildfire burning near Californi...
# 5  customsearch#result  Let it burn: US fights wildfires with fire, ba...
# 6  customsearch#result  Two bodies found in area burned by California ...
# 7  customsearch#result  Thousands flee wildfire burning near Californi...
# 8  customsearch#result  Let it burn: US fights wildfires with fire, ba...
#
#                                            htmlTitle  \
# 0  Two bodies found in area burned by California ...
# 1  Thousands flee wildfire burning near Californi...
# 2  Let it burn: US fights wildfires with <b>fire<...
# 3  Two bodies found in area burned by California ...
# 4  Thousands flee wildfire burning near Californi...
# 5  Let it burn: US fights wildfires with <b>fire<...
# 6  Two bodies found in area burned by California ...
# 7  Thousands flee wildfire burning near Californi...
# 8  Let it burn: US fights wildfires with <b>fire<...
#
#                                                 link        displayLink  \
# 0  https://www.malaymail.com/amp/news/world/2016/...  www.malaymail.com
# 1  https://www.malaymail.com/news/world/2018/07/2...  www.malaymail.com
# 2  https://www.malaymail.com/news/world/2019/08/2...  www.malaymail.com
# 3  https://www.malaymail.com/amp/news/world/2016/...  www.malaymail.com
# 4  https://www.malaymail.com/news/world/2018/07/2...  www.malaymail.com
# 5  https://www.malaymail.com/news/world/2019/08/2...  www.malaymail.com
# 6  https://www.malaymail.com/amp/news/world/2016/...  www.malaymail.com
# 7  https://www.malaymail.com/news/world/2018/07/2...  www.malaymail.com
# 8  https://www.malaymail.com/news/world/2019/08/2...  www.malaymail.com
#
#                                              snippet  \
# 0  Jun 30, 2016 ... LOS ANGELES, June 30 — Two bo...
# 1  Jul 27, 2018 ... The Cranston Fire was one of ...
# 2  Aug 28, 2019 ... Except this fire was delibera...
# 3  Jun 30, 2016 ... LOS ANGELES, June 30 — Two bo...
# 4  Jul 27, 2018 ... The Cranston Fire was one of ...
# 5  Aug 28, 2019 ... Except this fire was delibera...
# 6  Jun 30, 2016 ... LOS ANGELES, June 30 — Two bo...
# 7  Jul 27, 2018 ... The Cranston Fire was one of ...
# 8  Aug 28, 2019 ... Except this fire was delibera...
#
#                                          htmlSnippet       cacheId  \
# 0  Jun 30, 2016 <b>...</b> LOS ANGELES, June 30 —...  ja4VL5YPMGAJ
# 1  Jul 27, 2018 <b>...</b> The Cranston <b>Fire</...  WryAcJGZ-G8J
# 2  Aug 28, 2019 <b>...</b> Except this <b>fire</b...  lJvZk34eJRwJ
# 3  Jun 30, 2016 <b>...</b> LOS ANGELES, June 30 —...  ja4VL5YPMGAJ
# 4  Jul 27, 2018 <b>...</b> The Cranston <b>Fire</...  WryAcJGZ-G8J
# 5  Aug 28, 2019 <b>...</b> Except this <b>fire</b...  lJvZk34eJRwJ
# 6  Jun 30, 2016 <b>...</b> LOS ANGELES, June 30 —...  ja4VL5YPMGAJ
# 7  Jul 27, 2018 <b>...</b> The Cranston <b>Fire</...  WryAcJGZ-G8J
# 8  Aug 28, 2019 <b>...</b> Except this <b>fire</b...  lJvZk34eJRwJ
#
#                                         formattedUrl  \
# 0  https://www.malaymail.com/amp/news/world/...in...
# 1  https://www.malaymail.com/news/world/2018/07/....
# 2  https://www.malaymail.com/news/world/...it...w...
# 3  https://www.malaymail.com/amp/news/world/...in...
# 4  https://www.malaymail.com/news/world/2018/07/....
# 5  https://www.malaymail.com/news/world/...it...w...
# 6  https://www.malaymail.com/amp/news/world/...in...
# 7  https://www.malaymail.com/news/world/2018/07/....
# 8  https://www.malaymail.com/news/world/...it...w...
#
#                                     htmlFormattedUrl  \
# 0  https://www.malaymail.com/amp/news/world/...in...
# 1  https://www.malaymail.com/news/world/2018/07/....
# 2  https://www.malaymail.com/news/world/...it...w...
# 3  https://www.malaymail.com/amp/news/world/...in...
# 4  https://www.malaymail.com/news/world/2018/07/....
# 5  https://www.malaymail.com/news/world/...it...w...
# 6  https://www.malaymail.com/amp/news/world/...in...
# 7  https://www.malaymail.com/news/world/2018/07/....
# 8  https://www.malaymail.com/news/world/...it...w...
#
#                                              pagemap
# 0  {'metatags': [{'og:image': 'https://media.mala...
# 1  {'metatags': [{'og:image': 'https://media.mala...
# 2  {'cse_thumbnail': [{'src': 'https://encrypted-...
# 3  {'metatags': [{'og:image': 'https://media.mala...
# 4  {'metatags': [{'og:image': 'https://media.mala...
# 5  {'cse_thumbnail': [{'src': 'https://encrypted-...
# 6  {'metatags': [{'og:image': 'https://media.mala...
# 7  {'metatags': [{'og:image': 'https://media.mala...
# 8  {'cse_thumbnail': [{'src': 'https://encrypted-...

# %%
# Only displayLink, link, htmlSnippet, htmlTitle, snippet are useful for export, so let's isolate
# df_export = df.loc[:, ["displayLink", "link", "htmlSnippet", "htmlTitle", "snippet"]]
# df_export = df.loc[:, ['kind', 'title', 'htmlTitle', 'link', 'displayLink', 'snippet', 'htmlSnippet', 'cacheId', 'formattedUrl', 'htmlFormattedUrl', 'pagemap']]
df_export = df.loc[:, ['kind', 'title', 'htmlTitle', 'link', 'displayLink', 'snippet', 'htmlSnippet', 'cacheId', 'formattedUrl', 'htmlFormattedUrl', 'pagemap']]
df_export
# Out:
#                   kind                                              title  \
# 0  customsearch#result  Two bodies found in area burned by California ...
# 1  customsearch#result  Thousands flee wildfire burning near Californi...
# 2  customsearch#result  Let it burn: US fights wildfires with fire, ba...
# 3  customsearch#result  Two bodies found in area burned by California ...
# 4  customsearch#result  Thousands flee wildfire burning near Californi...
# 5  customsearch#result  Let it burn: US fights wildfires with fire, ba...
# 6  customsearch#result  Two bodies found in area burned by California ...
# 7  customsearch#result  Thousands flee wildfire burning near Californi...
# 8  customsearch#result  Let it burn: US fights wildfires with fire, ba...
#
#                                            htmlTitle  \
# 0  Two bodies found in area burned by California ...
# 1  Thousands flee wildfire burning near Californi...
# 2  Let it burn: US fights wildfires with <b>fire<...
# 3  Two bodies found in area burned by California ...
# 4  Thousands flee wildfire burning near Californi...
# 5  Let it burn: US fights wildfires with <b>fire<...
# 6  Two bodies found in area burned by California ...
# 7  Thousands flee wildfire burning near Californi...
# 8  Let it burn: US fights wildfires with <b>fire<...
#
#                                                 link        displayLink  \
# 0  https://www.malaymail.com/amp/news/world/2016/...  www.malaymail.com
# 1  https://www.malaymail.com/news/world/2018/07/2...  www.malaymail.com
# 2  https://www.malaymail.com/news/world/2019/08/2...  www.malaymail.com
# 3  https://www.malaymail.com/amp/news/world/2016/...  www.malaymail.com
# 4  https://www.malaymail.com/news/world/2018/07/2...  www.malaymail.com
# 5  https://www.malaymail.com/news/world/2019/08/2...  www.malaymail.com
# 6  https://www.malaymail.com/amp/news/world/2016/...  www.malaymail.com
# 7  https://www.malaymail.com/news/world/2018/07/2...  www.malaymail.com
# 8  https://www.malaymail.com/news/world/2019/08/2...  www.malaymail.com
#
#                                              snippet  \
# 0  Jun 30, 2016 ... LOS ANGELES, June 30 — Two bo...
# 1  Jul 27, 2018 ... The Cranston Fire was one of ...
# 2  Aug 28, 2019 ... Except this fire was delibera...
# 3  Jun 30, 2016 ... LOS ANGELES, June 30 — Two bo...
# 4  Jul 27, 2018 ... The Cranston Fire was one of ...
# 5  Aug 28, 2019 ... Except this fire was delibera...
# 6  Jun 30, 2016 ... LOS ANGELES, June 30 — Two bo...
# 7  Jul 27, 2018 ... The Cranston Fire was one of ...
# 8  Aug 28, 2019 ... Except this fire was delibera...
#
#                                          htmlSnippet       cacheId  \
# 0  Jun 30, 2016 <b>...</b> LOS ANGELES, June 30 —...  ja4VL5YPMGAJ
# 1  Jul 27, 2018 <b>...</b> The Cranston <b>Fire</...  WryAcJGZ-G8J
# 2  Aug 28, 2019 <b>...</b> Except this <b>fire</b...  lJvZk34eJRwJ
# 3  Jun 30, 2016 <b>...</b> LOS ANGELES, June 30 —...  ja4VL5YPMGAJ
# 4  Jul 27, 2018 <b>...</b> The Cranston <b>Fire</...  WryAcJGZ-G8J
# 5  Aug 28, 2019 <b>...</b> Except this <b>fire</b...  lJvZk34eJRwJ
# 6  Jun 30, 2016 <b>...</b> LOS ANGELES, June 30 —...  ja4VL5YPMGAJ
# 7  Jul 27, 2018 <b>...</b> The Cranston <b>Fire</...  WryAcJGZ-G8J
# 8  Aug 28, 2019 <b>...</b> Except this <b>fire</b...  lJvZk34eJRwJ
#
#                                         formattedUrl  \
# 0  https://www.malaymail.com/amp/news/world/...in...
# 1  https://www.malaymail.com/news/world/2018/07/....
# 2  https://www.malaymail.com/news/world/...it...w...
# 3  https://www.malaymail.com/amp/news/world/...in...
# 4  https://www.malaymail.com/news/world/2018/07/....
# 5  https://www.malaymail.com/news/world/...it...w...
# 6  https://www.malaymail.com/amp/news/world/...in...
# 7  https://www.malaymail.com/news/world/2018/07/....
# 8  https://www.malaymail.com/news/world/...it...w...
#
#                                     htmlFormattedUrl  \
# 0  https://www.malaymail.com/amp/news/world/...in...
# 1  https://www.malaymail.com/news/world/2018/07/....
# 2  https://www.malaymail.com/news/world/...it...w...
# 3  https://www.malaymail.com/amp/news/world/...in...
# 4  https://www.malaymail.com/news/world/2018/07/....
# 5  https://www.malaymail.com/news/world/...it...w...
# 6  https://www.malaymail.com/amp/news/world/...in...
# 7  https://www.malaymail.com/news/world/2018/07/....
# 8  https://www.malaymail.com/news/world/...it...w...
#
#                                              pagemap
# 0  {'metatags': [{'og:image': 'https://media.mala...
# 1  {'metatags': [{'og:image': 'https://media.mala...
# 2  {'cse_thumbnail': [{'src': 'https://encrypted-...
# 3  {'metatags': [{'og:image': 'https://media.mala...
# 4  {'metatags': [{'og:image': 'https://media.mala...
# 5  {'cse_thumbnail': [{'src': 'https://encrypted-...
# 6  {'metatags': [{'og:image': 'https://media.mala...
# 7  {'metatags': [{'og:image': 'https://media.mala...
# 8  {'cse_thumbnail': [{'src': 'https://encrypted-...

# %%
url_scrap = df_export['formattedUrl'][7]
url_scrap
# Out:
# 'https://www.malaymail.com/news/world/2018/07/...wildfire.../1656522'

# %%
response = requests.get(url_scrap)

# %%
response.text
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n<head>\n\n<meta charset="utf-8">\n\n<title>Not Found | Malay Mail</title>\n<script type="application/ld+json">\n    {\n    "keywords": [\n        "Malay Mail",\n        "Malaymail",\n        "Malaysia",\n        "Malaysian",\n        "News",\n        "Politics",\n        "Sports",\n        "Elections",\n        "World",\n        "Business",\n        "Sports",\n        "Showbiz",\n        "Entertainment",\n        "Tech",\n        "Technology",\n        "Drive",\n        "Cars",\n        "Property",\n        "Features",\n        "Life",\n        "Opinion",\n        "Food",\n        "Columnist",\n        "Computer",\n        "Bank",\n        "Travel",\n        "Directory",\n        "Education",\n        "Eat",\n        "Drink",\n        "Dining"\n    ],\n    "headline": "Malay Mail",\n    "description": "The star of the latest Malaysia news, news on politics, lifestyle, opinions & the world.",\n    "@context": "https:\\/\\/schema.org",\n    "@type": "WebPage",\n    "mainEntityOfPage": {\n        "@type": "WebPage",\n        "@id": "https:\\/\\/www.malaymail.com\\/news\\/world\\/2018\\/07\\/...wildfire...\\/1656522"\n    },\n    "image": {\n        "@type": "ImageObject",\n        "url": "https:\\/\\/www.malaymail.com\\/graphics\\/meta\\/og-image.png",\n        "width": 1200,\n        "height": 630\n    },\n    "author": {\n        "@type": "Organization",\n        "name": "Malay Mail"\n    },\n    "publisher": {\n        "@type": "Organization",\n        "name": "Malay Mail",\n        "logo": {\n            "@type": "ImageObject",\n            "url": "https:\\/\\/www.malaymail.com\\/graphics\\/meta\\/main\\/logo-structured.png",\n            "width": 238,\n            "height": 60\n        }\n    }\n}\n</script>\n<meta name="keywords" content="Malay Mail, Malaymail, Malaysia, Malaysian, News, Politics, Sports, Elections, World, Business, Sports, Showbiz, Entertainment, Tech, Technology, Drive, Cars, Property, Features, Life, Opinion, Food, Columnist, Computer, Bank, Travel, Directory, Education, Eat, Drink, Dining" />\n<meta property="fb:app_id" content="1709756459249190" />\n<meta property="fb:pages" content="163335377171805" />\n<meta name="twitter:site" content="@malaymail" />\n<meta name="twitter:creator" content="@malaymail" />\n<meta name="twitter:card" content="summary_large_image" />\n<meta property="og:title" content="Malay Mail">\n<meta name="twitter:title" content="Malay Mail">\n<meta property="og:type" content="website" />\n\n<link rel="canonical" href="https://www.malaymail.com/news/world/2018/07/...wildfire.../1656522">\n<meta property="og:url" content="https://www.malaymail.com/news/world/2018/07/...wildfire.../1656522">\n<meta name="twitter:url" content="https://www.malaymail.com/news/world/2018/07/...wildfire.../1656522">\n\n<meta name="description" content="The star of the latest Malaysia news, news on politics, lifestyle, opinions &amp; the world.">\n<meta property="og:description" content="The star of the latest Malaysia news, news on politics, lifestyle, opinions &amp; the world.">\n<meta name="twitter:description" content="The star of the latest Malaysia news, news on politics, lifestyle, opinions &amp; the world.">\n\n<meta property="og:image" content="https://www.malaymail.com/graphics/meta/og-image.png">\n<meta name="twitter:image" content="https://www.malaymail.com/graphics/meta/og-image.png">\n\n<link rel="icon" type="image/png" href="https://www.malaymail.com/graphics/meta/main/logo-32x32.png">\n<link rel="icon" sizes="152x152" href="https://www.malaymail.com/graphics/meta/main/logo-152x152.png">\n\n<link rel="apple-touch-icon" href="https://www.malaymail.com/graphics/meta/main/logo-76x76.png">\n<link rel="apple-touch-icon" sizes="76x76" href="https://www.malaymail.com/graphics/meta/main/logo-76x76.png">\n<link rel="apple-touch-icon" sizes="120x120" href="https://www.malaymail.com/graphics/meta/main/logo-120x120.png">\n<link rel="apple-touch-icon" sizes="152x152" hr ...

# %%
soup.find_all('p')
# Out:
# [<p class="py-3 m-0 text-center">Loading...</p>,
#  <p class="mb-0">No articles found.</p>,
#  <p class="text-center">Loading...</p>,
#  <p class="small text-muted mb-0">© 2020, Malay Mail, All Rights Reserved.</p>]

# %%
def get_only_text(url):
    page = urllib.request.urlopen(url).read().decode('utf8')
    soup = BeautifulSoup(page, "lxml")
    text = ' '.join(map(lambda p: p.text, soup.find_all('article')))
    soup2 = BeautifulSoup(text, "lxml")
    text = ' '.join(map(lambda p: p.text, soup2.find_all('p')))
    return soup.title.text, text

# %%
textOfUrl = get_only_text('https://www.malaymail.com/news/world/...it...wildfires...fire.../1785149')
text
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-127-b15eef43b759> in <module>
# ----> 1 textOfUrl = get_only_text('https://www.malaymail.com/news/world/...it...wildfires...fire.../1785149')
#       2 text
#
# <ipython-input-115-a9d65e413804> in get_only_text(url)
#       1 def get_only_text(url):
# ----> 2     page = urllib.request.urlopen(url).read().decode('utf8')
#       3     soup = BeautifulSoup(page, "lxml")
#       4     text = ' '.join(map(lambda p: p.text, soup.find_all('article')))
#       5     soup2 = BeautifulSoup(text, "lxml")
#
# ~\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~\Anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#     643         return response
#
# ~\Anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~\Anaconda3\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 403: Forbidden
